# %%
# !pip install -U langchain langchain-community langchain-huggingface langchain-text-splitters chromadb sentence-transformers pypdf
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-community in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-huggingface in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-text-splitters in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (1.1.1)
# Collecting langchain-text-splitters
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: chromadb in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (1.5.8)
# Requirement already satisfied: sentence-transformers in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (5.4.1)
# Requirement already satisfied: pypdf in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (6.10.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.3.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-huggingface) (1.9.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2024.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typer in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.19.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.4.4)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (5.5.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.4.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: pyproject_hooks in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-proto==1.41.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: langchain-text-splitters
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 1.1.1
#     Uninstalling langchain-text-splitters-1.1.1:
#       Successfully uninstalled langchain-text-splitters-1.1.1
# Successfully installed langchain-text-splitters-1.1.2

# %%
# !pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-text-splitters) (1.3.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.11.7)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.10.0)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-huggingface
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (1.2.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-huggingface) (1.9.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-huggingface) (1.3.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2024.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typer in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.19.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.14.1)
# Requirement already satisfied: anyio in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.10.0)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.7.30)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.11.7)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.5.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (14.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.1.2)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pypdf

from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("sample.pdf")
documents = loader.load()

print(len(documents))
# Out:
# Requirement already satisfied: pypdf in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (6.10.2)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 3

# %%
text_splitter = CharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

docs = text_splitter.split_documents(documents)

print(f"Total chunks: {len(docs)}")
# Out:
# Total chunks: 3

# %%
embedding_model = HuggingFaceEmbeddings()

db = Chroma.from_documents(docs, embedding_model)

print("Vector DB created successfully")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Vector DB created successfully

# %%
query = input("Enter your question: ")
# Out:
# Enter your question:  what is rag?

# %%
results = db.similarity_search(query, k=3)

context = " ".join([doc.page_content for doc in results])

print(context[:500])
# Out:
# Customer Support Knowledge Base for RAG System
#
# 1. Introduction
# Customer support systems are essential for handling user queries efficiently. Traditional
# systems rely on manual responses or predefined FAQs, which can be slow and limited. To
# improve this, modern systems use artificial intelligence techniques like Retrieval-Augmented
# Generation (RAG).
#
# 2. What is RAG?
# RAG (Retrieval-Augmented Generation) is a technique that combines two processes:
# • Retrieval: Finding relevant informatio

# %%
query = input("Enter your question: ")
# Out:
# Enter your question:  how does the system works?

# %%
results = db.similarity_search(query, k=3)

context = " ".join([doc.page_content for doc in results])

print(context[:500])
# Out:
# Converts text into numerical form for similarity comparison.
# 4.4 Vector Database (ChromaDB)
# Stores embeddings and allows fast retrieval.
# 4.5 Retriever
# Finds the most relevant chunks based on user query.
# 4.6 LLM (Large Language Model)
# Generates human-like responses using retrieved context.
#
# 5. What is ChromaDB?
# ChromaDB is a lightweight vector database used to store embeddings. It helps in quickly
# retrieving similar data based on queries.
#
# 6. What is LangGraph?
# LangGraph is a framewo

# %%
print("RAG System executed successfully")
# Out:
# RAG System executed successfully
